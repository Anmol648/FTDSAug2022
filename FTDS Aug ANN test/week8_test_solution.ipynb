# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
# set the seed for the same result
import tensorflow
from numpy.random import seed
np.random.seed(1)
PYTHONHASHSEED=0
tensorflow.random.set_seed(2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Read the dataframe
columns=["Class", "age", "menopause", "tumor-size", "inv-nodes", "node-caps", "deg-malig", "breast", "breast-quad", "irradiat"]
df = pd.read_csv('/content/drive/MyDrive/breast-cancer.data.csv', header=None, names =columns)
X = df.iloc[:, 2:9].values
y = df.iloc[:, 0:1].values
df
# Out:
#                     Class    age menopause tumor-size inv-nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4    no-recurrence-events  40-49   premeno        0-4       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34       3-5        no
# 285     recurrence-events  50-59      ge40      30-34       3-5        no
#
#      deg-malig breast breast-quad irradiat
# 0            3   left    left_low       no
# 1            2  right    right_up       no
# 2            2   left    left_low       no
# 3            2  right     left_up       no
# 4            2  right   right_low       no
# ..         ...    ...         ...      ...
# 281          2   left     left_up       no
# 282          3   left     left_up      yes
# 283          1  right     left_up       no
# 284          3   left    left_low       no
# 285          3   left    left_low       no
#
# [286 rows x 10 columns]

# %%
# we map the target value as 1 if it is recurrence events , and 0 else
df['Target'] = df['Class'].map(lambda x: 1 if x=='recurrence-events' else 0 )
# drop the original 'Class' column
df.drop("Class", axis=1,inplace=True)

target = df[['Target']]
df.drop('Target', axis = 1, inplace = True)

# %%
# Question 1:
# we want to encode the age column as follows:
# if age is 20-29, encode as 1
# if age is 30-39, encode as 2,... so on
# if age is 70-79, encode as 6
# return a new Series called cancer['newAge']

def modifyAge():
    def changeAge(x):
        # YOUR CODE STARTS HERE
        #HINT: write if-else statement to return
        #the correct number for each age category
      if x =='20-29':
        return 1
      elif x =='30-39':
        return 2
      elif x =='40-49':
        return 3
      elif x =='50-59':
        return 4
      elif x =='60-69':
        return 5
      elif x =='70-79':
        return 6
        # YOUR CODE ENDS HERE
    df['age'] = df['age'].apply(lambda x: changeAge(x))
    return df['age']

# DO NOT EDIT THE BELOW CODE
modifyAge()
# DO NOT EDIT THE ABOVE CODE

# we will do similar encoding with the tumor size
# DO NOT EDIT THIS BELOW CODE
def changeTumor(x):
    if x == '0-4':
        return 1
    elif x == '5-9':
        return 2
    elif x == '10-14':
        return 3
    elif x == '15-19':
        return 4
    elif x == '20-24':
        return 5
    elif x == '25-29':
        return 6
    elif x == '30-34':
        return 7
    elif x == '35-39':
        return 8
    elif x == '40-44':
        return 9
    elif x == '45-49':
        return 10
    elif x == '50-54':
        return 11

df['tumor-size']=df['tumor-size'].apply(lambda x: changeTumor(x))
# DO NOT EDIT THIS ABOVE CODE

# we will do similar encoding with inv-nodes
# DO NOT EDIT THIS BELOW CODE
def changeInv(x):
    if x == '0-2':
        return 1
    elif x == '3-5':
        return 2
    elif x == '6-8':
        return 3
    elif x == '9-11':
        return 4
    elif x == '12-14':
        return 5
    elif x == '15-17':
        return 6
    elif x == '24-26':
        return 7

df['inv-nodes'] = df['inv-nodes'].apply(lambda x: changeInv(x))
# DO NOT EDIT THIS ABOVE CODE

# Now, we will one hot encode other categorical columns
df_dummies = pd.get_dummies(df, drop_first=True)

# we assign cancer_dummies as new_df
new_df = df_dummies

# %%
def question2():
    # YOUR CODE STARTS HERE
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)
    # YOUR CODE ENDS HERE
    return X_train, X_test, y_train, y_test

# DO NOT EDIT THE BELOW CODE
X_train, X_test, y_train, y_test = question2()
# DO NOT EDIT THE ABOVE CODE

# %%
# Question 3
# Scale X_train and X_test using Standard Scaler
# Import all necessary modules
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
def question3():
    # YOUR CODE STARTS HERE
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # YOUR CODE ENDS HERE
    return X_train_scaled, X_test_scaled


# DO NOT EDIT THE BELOW CODE
X_train_scaled, X_test_scaled = question3()
# DO NOT EDIT THE ABOVE CODE
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-8672a6b1ff8f> in <module>
#       4 from sklearn.preprocessing import StandardScaler
#       5 sc = StandardScaler()
# ----> 6 X_train = sc.fit_transform(X_train)
#       7 X_test = sc.transform(X_test)
#       8 def question3():
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     839         """
#     840         first_call = not hasattr(self, "n_samples_seen_")
# --> 841         X = self._validate_data(
#     842             X,
#     843             accept_sparse=("csr", "csc"),
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ValueError: could not convert string to float: '40-49'

# %%
# Part 2 - Now let's make the ANN!
# Importing all the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Make the neural network as follows
# 1st layer: use Dense layer, with 32 units, uniform kernel initializer, relu activation,
# you have to figure out the input_dim
# 2nd layer: use Dense layer, with 32 units, uniform kernel initializer, relu activation
# 3rd layer: use Dense layer, with 32 units, uniform kernel initializer, relu activation
# 4th layer: use Dense layer, with 32 units, uniform kernel initializer, relu activation
# 5th layer: you have to figure out the number of output units and the activation function you use,
# use uniform kernel initializer.

# After that, compile the ANN with adam optimizer, use accuracy as metrics and
# figure out the appropriate loss function.

# After that, fit the model with 50 batch_size, and 20 epochs

# Then, return the loss and accuracy
def question4():
    # YOUR CODE STARTS HERE
    # Initialising the ANN
    classifier = Sequential()
    classifier.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
    classifier.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
    classifier.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
    classifier.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
    classifier.add(Dense(units = 3, kernel_initializer = 'uniform', activation = 'sigmoid')) 
    # Compiling the ANN
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    # Fitting the ANN to the Training set
    classifier.fit(X_train, batch_size = 50, epochs = 20)
    # Part 3 - Making predictions and evaluating the model
    # Predicting the Test set results
    y_pred_ann = classifier.predict(X_test)
    y_pred_ann = (y_pred_ann > 0.5)

    cm3 = confusion_matrix(y_test, y_pred_ann)
    print(cm3)
    # Making the Confusion Matrix
    from sklearn.metrics import accuracy_score

    score3 = accuracy_score(y_test,y_pred_ann)
    print(score3*100)









    # YOUR CODE ENDS HERE
    return loss, accuracy

loss, accuracy = question4()
print(loss)
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-2b4a2a2ceb87> in <module>
#      51     return loss, accuracy
#      52
# ---> 53 loss, accuracy = question4()
#      54 print(loss)
#      55 print(accuracy)
#
# <ipython-input-31-2b4a2a2ceb87> in question4()
#      26     classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
#      27     # Fitting the ANN to the Training set
# ---> 28     classifier.fit(X_train, batch_size = 50, epochs = 20)
#      29     # Part 3 - Making predictions and evaluating the model
#      30     # Predicting the Test set results
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type int).
